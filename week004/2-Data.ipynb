# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Loading thhe dataset

fumkin = pd.read_csv('pumpkins.csv')

# %%
# This visualization doesnt make any sense, lets clean the data and explore it.

fumkin.plot()
# Out:
# <AxesSubplot:>

# %%
# Checking the missing values
fumkin.isnull().sum()
# Out:
# City Name             0
# Type               1712
# Package               0
# Variety               5
# Sub Variety        1461
# Grade              1757
# Date                  0
# Low Price             0
# High Price            0
# Mostly Low          103
# Mostly High         103
# Origin                3
# Origin District    1626
# Item Size           279
# Color               616
# Environment        1757
# Unit of Sale       1595
# Quality            1757
# Condition          1757
# Appearance         1757
# Storage            1757
# Crop               1757
# Repack                0
# Trans Mode         1757
# Unnamed: 24        1757
# Unnamed: 25        1654
# dtype: int64

# %%
# Dropping the columns with missing values

new_columns = ['City Name', 'Package', 'Low Price', 'High Price', 'Date']
fumkin = fumkin.drop([i for  i  in fumkin.columns if i not in new_columns], axis=1)
fumkin.head()
# Out:
#    City Name       Package     Date  Low Price  High Price
# 0  BALTIMORE  24 inch bins  4/29/17      270.0       280.0
# 1  BALTIMORE  24 inch bins   5/6/17      270.0       280.0
# 2  BALTIMORE  24 inch bins  9/24/16      160.0       160.0
# 3  BALTIMORE  24 inch bins  9/24/16      160.0       160.0
# 4  BALTIMORE  24 inch bins  11/5/16       90.0       100.0

# %%
# Taking the average of low price and high price

price = (fumkin['Low Price'] + fumkin['High Price']) / 2

# %%
# Creating new dataframe

fumfum = pd.DataFrame({'CityName': fumkin['City Name'], 'Date':fumkin['Date'], 'Package': fumkin['Package'], 'LowPrice': fumkin['Low Price'],'HighPrice': fumkin['High Price'], 'Price': price})
fumfum.head()
# Out:
#     CityName     Date       Package  LowPrice  HighPrice  Price
# 0  BALTIMORE  4/29/17  24 inch bins     270.0      280.0  275.0
# 1  BALTIMORE   5/6/17  24 inch bins     270.0      280.0  275.0
# 2  BALTIMORE  9/24/16  24 inch bins     160.0      160.0  160.0
# 3  BALTIMORE  9/24/16  24 inch bins     160.0      160.0  160.0
# 4  BALTIMORE  11/5/16  24 inch bins      90.0      100.0   95.0

# %%
# Displaying average priceon each city using matplotlib library

x = new_pumpkins.Price
y = new_pumpkins.CityName
plt.scatter(x, y)
plt.show()

# %%
# Visualizing the average prices and the date on each city using seaborn library

sns.relplot(data=fumfum, x='Price', y='CityName', hue='Date', palette='YlOrBr', height=15, aspect=.5)
plt.show()
