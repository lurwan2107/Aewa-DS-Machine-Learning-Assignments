# %% [markdown]
# Trying New Dataset:

# %% [markdown]
# You've begun to learn about Time Series Forecasting by looking at the type of data that requires this special modeling. You've visualized some data around energy. Now, look around for some other data that would benefit from Time Series Forecasting. Find three examples and create a notebook to visualize them. Notate any special characteristics they have (seasonality, abrupt changes, or other trends) in the notebook.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# Loading the climate dataset
climate_data = pd.read_csv("C:/Users/PC/Desktop/Data/jena_climate_2009_2016.csv")
climate_data.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
climate_data.columns
# Out:
# Index(['Date Time', 'p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)',
#        'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'wv (m/s)', 'max. wv (m/s)',
#        'wd (deg)'],
#       dtype='object')

# %% [markdown]
# Example 1:

# %%
# Example 1:
climate_data.plot(y='p (mbar)', x='Date Time', subplots=True, figsize=(15,8), fontsize=12)
plt.xlabel('Date Time', fontsize=12)
plt.ylabel('p (mbar)', fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
climate_data[0:30526].plot(y='p (mbar)', x='Date Time', subplots=True, figsize=(15,8), fontsize=12)
plt.xlabel('Date Time', fontsize=12)
plt.ylabel('p (mbar)', fontsize=12)
plt.show()

# %% [markdown]
# Example 2:

# %%
# Example 2:
climate_data.plot(y='T (degC)', x='Date Time', subplots=True, figsize=(15,8), fontsize=12)
plt.xlabel('Date Time', fontsize=12)
plt.ylabel('T (degC)', fontsize=12)
plt.show()

# %%
climate_data[0:30526].plot(y='T (degC)', x='Date Time', subplots=True, figsize=(15,8), fontsize=12)
plt.xlabel('Date Time', fontsize=12)
plt.ylabel('T (degC)', fontsize=12)
plt.show()
