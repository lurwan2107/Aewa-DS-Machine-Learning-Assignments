# %%
import os
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
#from common.utils import load_data, mape

# %%
month = pd.read_csv("C:/Users/PC/Desktop/Data/Month_Value_1.csv")
month.head()
# Out:
#        Period       Revenue  Sales_quantity  Average_cost  \
# 0  01.01.2015  1.601007e+07         12729.0   1257.763541
# 1  01.02.2015  1.580759e+07         11636.0   1358.507000
# 2  01.03.2015  2.204715e+07         15922.0   1384.697024
# 3  01.04.2015  1.881458e+07         15227.0   1235.606705
# 4  01.05.2015  1.402148e+07          8620.0   1626.621765
#
#    The_average_annual_payroll_of_the_region
# 0                                30024676.0
# 1                                30024676.0
# 2                                30024676.0
# 3                                30024676.0
# 4                                30024676.0

# %%
month.columns
# Out:
# Index(['Period', 'Revenue', 'Sales_quantity', 'Average_cost',
#        'The_average_annual_payroll_of_the_region'],
#       dtype='object')

# %%
month.isnull().sum()
# Out:
# Period                                       0
# Revenue                                     32
# Sales_quantity                              32
# Average_cost                                32
# The_average_annual_payroll_of_the_region    32
# dtype: int64

# %%
month.info
# Out:
# <bound method DataFrame.info of         Period       Revenue  Sales_quantity  Average_cost  \
# 0   01.01.2015  1.601007e+07         12729.0   1257.763541
# 1   01.02.2015  1.580759e+07         11636.0   1358.507000
# 2   01.03.2015  2.204715e+07         15922.0   1384.697024
# 3   01.04.2015  1.881458e+07         15227.0   1235.606705
# 4   01.05.2015  1.402148e+07          8620.0   1626.621765
# ..         ...           ...             ...           ...
# 91  01.08.2022           NaN             NaN           NaN
# 92  01.09.2022           NaN             NaN           NaN
# 93  01.10.2022           NaN             NaN           NaN
# 94  01.11.2022           NaN             NaN           NaN
# 95  01.12.2022           NaN             NaN           NaN
#
#     The_average_annual_payroll_of_the_region
# 0                                 30024676.0
# 1                                 30024676.0
# 2                                 30024676.0
# ...

# %%
month.plot(y='Sales_quantity', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('Period', fontsize=12)
plt.ylabel('Sales_quantity', fontsize=12)
plt.show()

# %%
train_start_dt = '01.01.2015'
test_start_dt = '01.05.2015'

# %%
month[int(len(month.index < test_start_dt) & (month.index >= train_start_dt))][['Sales_quantity']].rename(columns={'Sales_quantity':'train'}) \
    .join(energy[test_start_dt:][['Sales_quantity']].rename(columns={'Sales_quantity':'test'}), how='outer') \
    .plot(y=['train', 'test'], figsize=(15, 8), fontsize=12)
plt.xlabel('Period', fontsize=12)
plt.ylabel('Sales_quantity', fontsize=12)
plt.show()
